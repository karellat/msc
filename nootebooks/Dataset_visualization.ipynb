# %%
from nilearn.plotting import plot_anat
import nibabel as nib

# %%
raw_path = "/home/karelto1/MRI/ADNI/002_S_0295/MPR__GradWarp__B1_Correction__N3__Scaled/2006-04-18_08_20_30.0/S13408/ADNI_002_S_0295_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070319113623975_S13408_I45108.nii"
raw_img = nib.load(raw_path)
plot_anat(raw_img)

# %%
cor_img = nib.load("/home/karelto1/MRI/minc_core/ad/_image_id_101549/ADNI_027_S_1385_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20080408153436647_S47223_I101549_normalized.nii")
plot_anat(cor_img)

# %%
cor_img = nib.load("/home/karelto1/MRI/minc_beast/ad/_image_id_101549/ADNI_027_S_1385_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20080408153436647_S47223_I101549_normalized_masked.nii")
plot_anat(cor_img)
